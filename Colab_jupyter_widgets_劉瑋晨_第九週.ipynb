# %% [markdown]
# <a href="https://colab.research.google.com/github/liuweichen789/MystanCodeProjects/blob/main/Colab_jupyter_widgets_%E5%8A%89%E7%91%8B%E6%99%A8_%E7%AC%AC%E4%B9%9D%E9%80%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Getting started

# %%
# !pip install ipywidgets
# To enable `ipywidgets`
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.6 MB/s eta 0:00:00
# ...
# Enabling notebook extension jupyter-js-widgets/extension...
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json
# Paths used for configuration of notebook:
#
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json

# %%
import pandas as pd
from ipywidgets import widgets
from IPython.display import display

# %% [markdown]
# ##Sliders

# %%
from IPython.display import display
slider = widgets.IntSlider()
display(slider)
# Out:
# IntSlider(value=0)

# %% [markdown]
# ##Button

# %%
btn = widgets.Button(description='Widget')
def button_eventhandler(obj):
    print('Hello from the {} button!'.format(obj.description))
btn.on_click(button_eventhandler)
display(btn)
# Out:
# Button(description='Widget', style=ButtonStyle())

# %% [markdown]
# ##Dropdown

# %%
import pandas as pd
url="https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dropdown = widgets.Dropdown(options =["None", "DF head", "DF info"])
output = widgets.Output()
def select(change):
  output.clear_output()
  if(change.new == 'None'):
    with output:
      display("Select an option")
  elif(change.new == 'DF head'):
    with output:
      display(df.head())
  elif(change.new == 'DF info'):
    with output:
      display(df.info())
  else:
    with output:
      display("Error: option not found")

dropdown.observe(select, names="value")
display(dropdown)
display(output)
# Out:
# Dropdown(options=('None', 'DF head', 'DF info'), value='None')
# Output()

# %% [markdown]
# ##Text field

# %%
text = widgets.Text(description="Text - ")
out = widgets.Output()
def select(change):
    out.clear_output()
    with out:
      display("Entered value - "+change.new)

text.observe(select, names="value")
display(text)
display(out)
# Out:
# Text(value='', description='Text - ')
# Output()

# %% [markdown]
# ##HBox and VBox

# %%
texth = widgets.Text(description="Text - ")
outh = widgets.Output()
def select(change):
    outh.clear_output()
    with outh:
      display("Entered value - "+change.new)

texth.observe(select, names="value")

hbox = widgets.HBox([texth, outh])
display(hbox)

# %%
text = widgets.Text(description="Text - ")
out = widgets.Output()
def select(change):
    out.clear_output()
    with out:
      display("Entered value - "+change.new)

text.observe(select, names="value")

vbox = widgets.VBox([text, out])
display(vbox)

# %% [markdown]
# ##Dashboard( Mini Panda's profiler)

# %%
#################-- DataFrame Head --#################
output_df_head = widgets.Output()
output_df_head.clear_output()
with output_df_head:
    print(df.head())

#################-- DataFrame Info --#################
output_df_info = widgets.Output()
output_df_info.clear_output()
with output_df_info:
    print(df.info())

#########-- Unique values in chosen column --#########
dropdown_columns = widgets.Dropdown(options = df.columns, description = "Column - ")
output_df_unique = widgets.Output()

def dropdown_columns_eventhandler(change):
  output_df_unique.clear_output()
  ot = df[change.new].unique()
  with output_df_unique:
    display(ot)

dropdown_columns.observe(dropdown_columns_eventhandler, names='value')
dashboard_unique = widgets.VBox([dropdown_columns, output_df_unique])

#########-- Graph b/w two different columns --########
output_df_graph = widgets.Output()
dropdown_c1 = widgets.Dropdown(options = df.columns, description = "Column x - ")
dropdown_c2 = widgets.Dropdown(options = df.columns, description = "Column y - ")

def common(x='PassengerId', y = 'Pclass'):
  output_df_graph.clear_output()
  df.plot(x=x, y=y, style='o')
  # with output_df_graph:
  #   display(gf)

def dropdown_c1_eventhandler(change):
    common(change.new, dropdown_c2.value)
def dropdown_c2_eventhandler(change):
    common(dropdown_c1.value, change.new)

dropdown_c1.observe(dropdown_c1_eventhandler, names='value')
dropdown_c2.observe(dropdown_c2_eventhandler, names='value')
columns_hbox = widgets.HBox([dropdown_c1, dropdown_c2])
dashboard_graph = widgets.VBox([columns_hbox, output_df_graph])

# %%
tab = widgets.Tab([output_df_head, output_df_info, dashboard_unique, dashboard_graph])
tab.set_title(0, 'DataFram Head')
tab.set_title(1, 'DataFram Info')
tab.set_title(2, 'Unique values in column')
tab.set_title(3, 'Graph: Column vs column')
display(tab)

# %% [markdown]
# ### Author
# Mohammad Ahmad (Research engineer intern)
# LinkedIn - https://www.linkedin.com/in/mohammad-ahmad-ai/
# Personal Blog - https://code-ml.com/
# GitHub - https://github.com/ahmadkhan242
# Twitter - https://twitter.com/ahmadkhan_242

# %%
widgets.FloatSlider(
    value=7.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='vertical',
    readout=True,
    readout_format='.1f',
)
# Out:
# FloatSlider(value=7.5, continuous_update=False, description='Test:', max=10.0, orientation='vertical', readout…

# %%
widgets.BoundedIntText(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Text:',
    disabled=False
)
# Out:
# BoundedIntText(value=7, description='Text:', max=10)

# %%
widgets.ToggleButton(
    value=False,
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)
# Out:
# ToggleButton(value=False, description='Click me', icon='check', tooltip='Description')

# %%
widgets.Dropdown(
    options=['1', '2', '3'],
    value='2',
    description='Number:',
    disabled=False,
)
# Out:
# Dropdown(description='Number:', index=1, options=('1', '2', '3'), value='2')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: 請用ipywidgets套件讓我可以選取 /content/drive/MyDrive/Colab Notebooks/TEJ/川普 資料夾裡面的檔案

import pandas as pd
import os
import ipywidgets as widgets
# from Ipywidgets import interact, interactive, fixed, interact_manual
from IPython.display import display

# Assuming you've mounted your Google Drive
# drive.mount('/content/drive')  # This line might already be in your code

# Specify the directory
directory_path = '/content/drive/MyDrive/Colab Notebooks/TEJ/川普'

# Check if the directory exists
if not os.path.exists(directory_path):
  print(f"Error: Directory '{directory_path}' not found.")
else:
  # Get a list of files in the directory
  file_list = [f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))]

  # Create a dropdown widget with file options
  file_dropdown = widgets.Dropdown(
      options=file_list,
      description='Select a file:'
  )

  # Define a function to handle file selection
  def on_file_selected(change):
      selected_file = change['new']
      file_path = os.path.join(directory_path, selected_file)
      print(f"Selected file: {file_path}")
      # Add your logic to process the selected file here
      # For example, you could read the file into a pandas DataFrame:
      # try:
      #     df = pd.read_csv(file_path)  # Adjust read function based on file type
      #     print(df.head())
      # except Exception as e:
      #     print(f"Error reading file: {e}")

  # Observe changes in the dropdown selection
  file_dropdown.observe(on_file_selected, names='value')

  # Display the dropdown widget
  display(file_dropdown)
# Out:
# Dropdown(description='Select a file:', options=('2330台積電周.xlsx', '2330台積電.xlsx', '2330台積電三大法人買賣超.xlsx', '2330台…

# %%
# prompt: 請用ipywidgets套件，顯示 /content/drive/MyDrive/Colab Notebooks/TEJ/川普 資料夾裡面的檔案的選項，讓我可以複數勾選輸出檔案

import ipywidgets as widgets
from IPython.display import display
import os

# Assuming you've mounted your Google Drive and the directory exists
directory_path = '/content/drive/MyDrive/Colab Notebooks/TEJ/川普'

if not os.path.exists(directory_path):
    print(f"Error: Directory '{directory_path}' not found.")
else:
    file_list = [f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))]

    # Create checkboxes for each file
    checkboxes = [widgets.Checkbox(value=False, description=file) for file in file_list]

    # Create a VBox to arrange the checkboxes
    checkbox_box = widgets.VBox(checkboxes)

    # Create a button to trigger the selection process
    select_button = widgets.Button(description="Select Files")

    # Function to handle button click
    def on_select_button_clicked(b):
        selected_files = [checkbox.description for checkbox in checkboxes if checkbox.value]
        print("Selected Files:")
        for file in selected_files:
            print(file)
            # Add your file processing logic here. Example:
            # file_path = os.path.join(directory_path, file)
            # try:
            #    # Process the file (e.g., read it, display it, etc.)
            #    # ... your code to process the file ...
            # except Exception as e:
            #    print(f"Error processing {file}: {e}")


    select_button.on_click(on_select_button_clicked)


    # Display the checkboxes and the button
    display(checkbox_box)
    display(select_button)
# Out:
# ...
# Button(description='Select Files', style=ButtonStyle())
# Selected Files:
# 2330台積電日.xlsx

# %%
# prompt: 顯示所選檔案內容

import pandas as pd
from ipywidgets import widgets
from IPython.display import display
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Specify the directory
directory_path = '/content/drive/MyDrive/Colab Notebooks/TEJ/川普'

# Check if the directory exists
if not os.path.exists(directory_path):
    print(f"Error: Directory '{directory_path}' not found.")
else:
    file_list = [f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))]

    # Create checkboxes for each file
    checkboxes = [widgets.Checkbox(value=False, description=file) for file in file_list]

    # Create a VBox to arrange the checkboxes
    checkbox_box = widgets.VBox(checkboxes)

    # Create a button to trigger the selection process
    select_button = widgets.Button(description="Select Files")

    # Function to handle button click
    def on_select_button_clicked(b):
        selected_files = [checkbox.description for checkbox in checkboxes if checkbox.value]
        print("Selected Files:")
        for file in selected_files:
            print(file)
            file_path = os.path.join(directory_path, file)
            try:
                with open(file_path, 'r', encoding='utf-8') as f: # Specify encoding for better compatibility
                    file_content = f.read()
                    print(f"\nContent of {file}:\n{file_content}")
            except Exception as e:
                print(f"Error processing {file}: {e}")


    select_button.on_click(on_select_button_clicked)


    # Display the checkboxes and the button
    display(checkbox_box)
    display(select_button)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# Button(description='Select Files', style=ButtonStyle())
# Selected Files:
# 2330台積電日.xlsx
# Error processing 2330台積電日.xlsx: 'utf-8' codec can't decode byte 0xe8 in position 15: invalid continuation byte

# %%
# prompt: 顯示出2330台積電日資料欄位

import pandas as pd

# Assuming df2330 is the DataFrame containing the data for 2330 (TSMC)
# Replace 'df2330' with the actual variable name if it's different.

try:
  print(df2330台積電日.columns) # Displays the columns of the DataFrame
except NameError:
  print("DataFrame 'df2330' not found. Please ensure the file containing the data is selected and processed correctly.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Index(['2330 台積電 -- 20200101-99999999', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')
